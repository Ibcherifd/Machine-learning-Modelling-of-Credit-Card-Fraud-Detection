# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibcherifd/Machine-learning-Modelling-of-Credit-Card-Fraud-Detection/blob/main/CreditCardFraudDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Define file path
file_path = "/content/Credit Cards Transactions.csv"
import pandas as pd

# Load the dataset
df = pd.read_csv(file_path)

# Display basic info
print("Dataset Loaded Successfully!")
print(df.info())

# Show the first 10 rows
df.head(10)
print("Dataset Loaded Successfully!")
print(df.info())

# Show the first 10 rows
df.head(10)
# Out:
# Dataset Loaded Successfully!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29799 entries, 0 to 29798
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    29799 non-null  int64
#  1   V1      29799 non-null  float64
#  2   V2      29799 non-null  float64
#  3   V3      29799 non-null  float64
#  4   V4      29799 non-null  float64
#  5   V5      29799 non-null  float64
#  6   V6      29798 non-null  float64
#  7   V7      29798 non-null  float64
#  8   V8      29798 non-null  float64
#  9   V9      29798 non-null  float64
#  10  V10     29798 non-null  float64
#  11  V11     29798 non-null  float64
#  12  V12     29798 non-null  float64
#  13  V13     29798 non-null  float64
#  14  V14     29798 non-null  float64
#  15  V15     29798 non-null  float64
#  16  V16     29798 non-null  float64
#  17  V17     29798 non-null  float64
#  18  V18     29798 non-null  float64
#  19  V19     29798 non-null  float64
# ...

# %%
# Check dataset structure
print("Dataset Structure:")
print(df.info())

# Check for missing values
print("\nMissing Values in Each Column:")
print(df.isnull().sum())

# Display basic statistics
print("\nDataset Summary Statistics:")
print(df.describe())
# Out:
# Dataset Structure:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29799 entries, 0 to 29798
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    29799 non-null  int64
#  1   V1      29799 non-null  float64
#  2   V2      29799 non-null  float64
#  3   V3      29799 non-null  float64
#  4   V4      29799 non-null  float64
#  5   V5      29799 non-null  float64
#  6   V6      29798 non-null  float64
#  7   V7      29798 non-null  float64
#  8   V8      29798 non-null  float64
#  9   V9      29798 non-null  float64
#  10  V10     29798 non-null  float64
#  11  V11     29798 non-null  float64
#  12  V12     29798 non-null  float64
#  13  V13     29798 non-null  float64
#  14  V14     29798 non-null  float64
#  15  V15     29798 non-null  float64
#  16  V16     29798 non-null  float64
#  17  V17     29798 non-null  float64
#  18  V18     29798 non-null  float64
#  19  V19     29798 non-null  float64
# ...

# %%
import matplotlib.pyplot as plt

# Count the occurrences of each class
class_counts = df['Class'].value_counts()

# Print class distribution
print("\nClass Distribution:")
print(class_counts)

# Plot class distribution
plt.figure(figsize=(6,4))
plt.bar(class_counts.index, class_counts.values, tick_label=['Legit (0)', 'Fraud (1)'])
plt.xlabel("Transaction Type")
plt.ylabel("Number of Transactions")
plt.title("Class Distribution of Credit Card Transactions")
plt.show()
# Out:
# Class Distribution:
# Class
# 0.0    29704
# 1.0       94
# Name: count, dtype: int64

# %%
import seaborn as sns

# Plot transaction amount distribution
plt.figure(figsize=(10, 5))
sns.histplot(df['Amount'], bins=50, kde=True)
plt.title("Transaction Amount Distribution")
plt.xlabel("Amount")
plt.ylabel("Frequency")
plt.show()

# Plot transaction time distribution
plt.figure(figsize=(10, 5))
sns.histplot(df['Time'], bins=50, kde=True)
plt.title("Transaction Time Distribution")
plt.xlabel("Time (seconds since first transaction)")
plt.ylabel("Frequency")
plt.show()

# %%
# Select a subset of PCA features to visualize
pca_features = ['V1', 'V2', 'V3', 'V4', 'V5']

# Plot boxplots to detect outliers
plt.figure(figsize=(12, 6))
df[pca_features].boxplot()
plt.title("Distribution of PCA Features")
plt.xticks(rotation=45)
plt.show()

# %%
# Split dataset into fraud and non-fraud transactions
df_fraud = df[df['Class'] == 1]
df_legit = df[df['Class'] == 0]

# Plot transaction amount distribution for both classes
plt.figure(figsize=(12, 5))
sns.histplot(df_legit['Amount'], bins=50, kde=True, label="Legit (0)", color="blue", alpha=0.6)
sns.histplot(df_fraud['Amount'], bins=50, kde=True, label="Fraud (1)", color="red", alpha=0.6)
plt.title("Transaction Amount Distribution (Fraud vs. Legit)")
plt.xlabel("Amount")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
# Select a few PCA features for visualization
pca_features = ['V1', 'V2', 'V3', 'V4', 'V5']

# Plot distributions for fraud vs. non-fraud transactions
plt.figure(figsize=(15, 8))

for i, feature in enumerate(pca_features):
    plt.subplot(2, 3, i+1)
    sns.kdeplot(df_legit[feature], label="Legit (0)", color="blue", alpha=0.5)
    sns.kdeplot(df_fraud[feature], label="Fraud (1)", color="red", alpha=0.5)
    plt.title(f"Distribution of {feature} (Fraud vs. Legit)")
    plt.legend()

plt.tight_layout()
plt.show()

# %%
# !pip install imbalanced-learn

# %%
import pandas as pd
from sklearn.preprocessing import RobustScaler

# Define file path
file_path = "/content/Credit Cards Transactions.csv"

# Load the dataset
df = pd.read_csv(file_path)  # Make sure this line is executed before using 'df'

# Define features to scale (excluding 'Class')
features = df.columns.difference(['Class'])

# Apply RobustScaler (handles outliers better than MinMaxScaler)
scaler = RobustScaler()
df[features] = scaler.fit_transform(df[features])

print("Outliers handled. Features have been scaled.")
df.head()
# Out:
# Outliers handled. Features have been scaled.
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -2.026108 -0.503957 -0.110463  1.480991  0.680121 -0.021195  0.546175
# 1 -2.026108  0.665613  0.143322 -0.490909  0.148222  0.325297  0.065886
# 2 -2.026061 -0.503291 -1.059453  0.846006  0.109116 -0.164612  1.725948
# 3 -2.026061 -0.323578 -0.194659  0.862467 -0.601838  0.264124  1.238123
# 4 -2.026014 -0.411564  0.601266  0.659212  0.122416 -0.081103  0.223072
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.303423  0.052709  0.375570  ...  0.114138  0.429039 -0.235188  0.002677
# 1 -0.009781  0.025320 -0.112634  ... -0.488486 -0.663002  0.583295 -0.555447
# 2  0.846277  0.352814 -1.105444  ...  0.887661  1.017462  3.706781 -1.034897
# 3  0.301466  0.614206 -1.004817  ... -0.147263  0.104273 -0.543804 -1.702128
# 4  0.650998 -0.691079  0.733478  ...  0.139920  1.049155 -0.339485  0.104675
#
# ...

# %%
from imblearn.over_sampling import SMOTE

# Define feature matrix (X) and target variable (y)
X = df.drop(columns=['Class'])
y = df['Class']

# Remove rows with NaN values in the target variable 'Class'
df = df.dropna(subset=['Class'])

# Update X and y after removing NaN values
X = df.drop(columns=['Class'])
y = df['Class']

# Apply SMOTE to balance classes
smote = SMOTE(sampling_strategy=0.2, random_state=42)  # Increase fraud cases to 20% of total
X_resampled, y_resampled = smote.fit_resample(X, y)

print("Class imbalance addressed. New distribution:")
print(pd.Series(y_resampled).value_counts())
# Out:
# Class imbalance addressed. New distribution:
# Class
# 0.0    94944
# 1.0    18988
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, stratify=y_resampled, random_state=42)

print("Data split into training and testing sets.")
print(f"Training size: {X_train.shape[0]}, Testing size: {X_test.shape[0]}")
# Out:
# Data split into training and testing sets.
# Training size: 91145, Testing size: 22787

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Train a Logistic Regression model
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)

# Make predictions
y_pred = log_reg.predict(X_test)

# Evaluate performance
print("📌 Model Evaluation (Logistic Regression)")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# 📌 Model Evaluation (Logistic Regression)
# Accuracy: 0.9805152060385307
# Precision: 0.9676519799219185
# Recall: 0.913638757240653
# F1 Score: 0.9398699891657638
#
# Confusion Matrix:
#  [[18873   116]
#  [  328  3470]]

# %%
from sklearn.ensemble import RandomForestClassifier

# Train a Random Forest model
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

# Make predictions
y_pred_rf = rf.predict(X_test)

# Evaluate performance
print("📌 Model Evaluation (Random Forest)")
print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Precision:", precision_score(y_test, y_pred_rf))
print("Recall:", recall_score(y_test, y_pred_rf))
print("F1 Score:", f1_score(y_test, y_pred_rf))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
# Out:
# 📌 Model Evaluation (Random Forest)
# Accuracy: 0.9995611532891561
# Precision: 0.9989462592202318
# Recall: 0.9984202211690363
# F1 Score: 0.998683170924414
#
# Confusion Matrix:
#  [[18985     4]
#  [    6  3792]]

# %%
# !pip install xgboost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Train an XGBoost model
xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
xgb.fit(X_train, y_train)

# Make predictions
y_pred_xgb = xgb.predict(X_test)

# Evaluate XGBoost model
print("📌 Model Evaluation (XGBoost)")
print("Accuracy:", accuracy_score(y_test, y_pred_xgb))
print("Precision:", precision_score(y_test, y_pred_xgb))
print("Recall:", recall_score(y_test, y_pred_xgb))
print("F1 Score:", f1_score(y_test, y_pred_xgb))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_xgb))
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [07:17:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 📌 Model Evaluation (XGBoost)
# Accuracy: 0.9998683459867468
# Precision: 0.9992107340173638
# Recall: 1.0
# F1 Score: 0.9996052112120016
#
# Confusion Matrix:
#  [[18986     3]
#  [    0  3798]]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
# Define parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],   # Number of trees
    'max_depth': [None, 10, 20],       # Depth of each tree
    'min_samples_split': [2, 5, 10],   # Minimum samples required to split a node
    'min_samples_leaf': [1, 2, 4]      # Minimum samples per leaf
}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV # Import RandomizedSearchCV

# Define parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],   # Number of trees
    'max_depth': [None, 10, 20],       # Depth of each tree
    'min_samples_split': [2, 5, 10],   # Minimum samples required to split a node
    'min_samples_leaf': [1, 2, 4]      # Minimum samples per leaf
}

# Create a RandomizedSearchCV object (or GridSearchCV)
random_search = RandomizedSearchCV( # You can use GridSearchCV instead if you prefer
    estimator=RandomForestClassifier(random_state=42),
    param_distributions=param_grid,
    n_iter=10, # Number of parameter settings that are sampled
    cv=5,       # Number of cross-validation folds
    scoring='f1', # Evaluation metric
    random_state=42,
    verbose=2 # Display detailed output during the search
)

# Fit the RandomizedSearchCV object to the training data
random_search.fit(X_train, y_train) # Replace X_train and y_train with your training data

# Get the best model with optimized hyperparameters
best_rf = random_search.best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.0min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.0min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.0min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.0min
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 4.3min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 4.3min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 4.2min
# ---------------------------------------------------------------------------
# ...

# %%
import joblib
from xgboost import XGBClassifier

# Assuming X_train and y_train are already defined
xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
xgb.fit(X_train, y_train)

# Assign the trained XGBoost model to best_xgb
best_xgb = xgb

# Save the fine-tuned XGBoost model
joblib.dump(best_xgb, "xgboost_fraud_detection.pkl")

print("📌 Model saved as xgboost_fraud_detection.pkl")
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [07:19:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 📌 Model saved as xgboost_fraud_detection.pkl

# %%
# Load the saved XGBoost model
loaded_model = joblib.load("xgboost_fraud_detection.pkl")

# Test with new transactions
new_predictions = loaded_model.predict(X_test[:5])  # Predict first 5 samples

print("📌 Predictions for new transactions:", new_predictions)
# Out:
# 📌 Predictions for new transactions: [0 1 0 0 1]

# %%
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Load the saved XGBoost model
loaded_model = joblib.load("xgboost_fraud_detection.pkl")

# Make predictions on the test set
y_pred = loaded_model.predict(X_test)

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Define labels
labels = ["Legitimate", "Fraud"]

# Plot the confusion matrix as a large heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)

# Titles and labels
plt.title("Confusion Matrix for Fine-Tuned XGBoost Model", fontsize=14)
plt.xlabel("Predicted Label", fontsize=12)
plt.ylabel("Actual Label", fontsize=12)

# Show plot
plt.show()

# %%
# Plot correlation matrix
plt.figure(figsize=(14, 10))
sns.heatmap(pd.DataFrame(X_train).corr(), cmap="coolwarm", annot=False, linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
from sklearn.metrics import precision_recall_curve

y_scores = loaded_model.predict_proba(X_test)[:, 1]
precision, recall, thresholds = precision_recall_curve(y_test, y_scores)

plt.figure(figsize=(8, 5))
plt.plot(recall, precision, marker=".", label="XGBoost")
plt.title("Precision-Recall Curve")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Get feature importance from the model
importance = loaded_model.feature_importances_
features = [f"V{i+1}" for i in range(X_train.shape[1])]

# Sort by importance
indices = np.argsort(importance)[::-1]

plt.figure(figsize=(10, 6))
plt.bar(range(X_train.shape[1]), importance[indices], align="center")
plt.xticks(range(X_train.shape[1]), [features[i] for i in indices], rotation=90)
plt.title("Feature Importance (XGBoost)")
plt.xlabel("Feature")
plt.ylabel("Importance Score")
plt.show()

# %%
from sklearn.metrics import precision_recall_curve
import numpy as np

# Replace 'model' with 'loaded_model' to use the loaded XGBoost model
y_scores = loaded_model.predict_proba(X_test)[:,1]
precision, recall, thresholds = precision_recall_curve(y_test, y_scores)

plt.figure(figsize=(8,6))
plt.plot(recall, precision, marker='.')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Class', y='Amount', data=df, palette='Set2')
plt.title('Boxplot of Transaction Amounts by Class')
plt.xlabel('Class')
plt.ylabel('Amount')
plt.xticks([0,1], ['Legitimate', 'Fraud'])
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-48-3f8bd6812418>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Class', y='Amount', data=df, palette='Set2')

# %%
import matplotlib.pyplot as plt
import xgboost as xgb
import pandas as pd
import joblib # Make sure joblib is imported

# Load your trained model using joblib.load
model = joblib.load("xgboost_fraud_detection.pkl")

# Ensure your feature names are in a list
# If using pandas DataFrame for X_train
feature_names = X_train.columns

# Plot feature importance
xgb.plot_importance(model, max_num_features=10, importance_type='gain', height=0.5,
                    show_values=False, xlabel='Importance Score')
plt.title('Top 10 Feature Importances (XGBoost)')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Assuming X_train and y_train are defined and available from previous code
logistic_model = LogisticRegression()  # Create an instance of the LogisticRegression model
logistic_model.fit(X_train, y_train)    # Train the model with your training data

y_pred_log = logistic_model.predict(X_test)

cm_log = confusion_matrix(y_test, y_pred_log)
disp_log = ConfusionMatrixDisplay(confusion_matrix=cm_log, display_labels=["Legit", "Fraud"])
disp_log.plot(cmap="Blues")
plt.title("Confusion Matrix - Logistic Regression")
plt.show()

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Assuming X_train and y_train are defined and available from previous code
xgboost_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)  # Define the XGBoost model
xgboost_model.fit(X_train, y_train)  # Train the model

y_pred_xgb = xgboost_model.predict(X_test)

cm_xgb = confusion_matrix(y_test, y_pred_xgb)
disp_xgb = ConfusionMatrixDisplay(confusion_matrix=cm_xgb, display_labels=["Legit", "Fraud"])
disp_xgb.plot(cmap="Oranges")
plt.title("Confusion Matrix - XGBoost")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [07:28:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Assuming X_train and y_train are defined and available from previous code
random_forest_model = RandomForestClassifier(n_estimators=100, random_state=42) # Define and train
random_forest_model.fit(X_train, y_train)

y_pred_rf = random_forest_model.predict(X_test)

cm_rf = confusion_matrix(y_test, y_pred_rf)
disp_rf = ConfusionMatrixDisplay(confusion_matrix=cm_rf, display_labels=["Legit", "Fraud"])
disp_rf.plot(cmap="Greens")
plt.title("Confusion Matrix - Random Forest")
plt.show()

# %%
sns.countplot(x='Class', data=df)
plt.title("Figure 1: Class Distribution Before SMOTE")
plt.show()

# %%
sns.countplot(x=y_resampled)
plt.title("Figure 2: Class Distribution After SMOTE")
plt.show()

# %%
sns.boxplot(x='Class', y='Amount', data=df)
plt.title("Figure 3: Boxplot of Transaction Amounts")
plt.show()

# %%
corr = df.corr()
corr = df.corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr, cmap='coolwarm', vmax=1.0, vmin=-1.0, linewidths=0.1)
plt.title("Figure 4: Correlation Heatmap of Features")
plt.show()

# %%
import xgboost as xgb # Make sure xgboost is imported

# Assuming 'model' is your trained XGBoost model
xgb.plot_importance(model, max_num_features=10)  # Use xgb.plot_importance()

plt.title("Figure 5: Feature Importance from XGBoost")
plt.show()

# %%
# !pip install shap
import shap # Import the SHAP library

# Use 'best_xgb' (or the variable you used to store your trained XGBoost model)
explainer = shap.Explainer(best_xgb)
shap_values = explainer(X_test)
shap.summary_plot(shap_values, X_test)

# %%
shap.dependence_plot("V12", shap_values.values, X_test)

# %%
ConfusionMatrixDisplay.from_estimator(logistic_model, X_test, y_test)
plt.title("Figure 8: Confusion Matrix - Logistic Regression")
plt.show()

# %%
ConfusionMatrixDisplay.from_estimator(rf_model, X_test, y_test)
plt.title("Figure 9: Confusion Matrix - Random Forest")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-dc465cb2a1c1> in <cell line: 0>()
# ----> 1 ConfusionMatrixDisplay.from_estimator(rf_model, X_test, y_test)
#       2 plt.title("Figure 9: Confusion Matrix - Random Forest")
#       3 plt.show()
#
# NameError: name 'rf_model' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Assuming X_train and y_train are defined and available from previous code
rf_model = RandomForestClassifier(n_estimators=100, random_state=42) # Define and train
rf_model.fit(X_train, y_train)

y_pred_rf = rf_model.predict(X_test)

cm_rf = confusion_matrix(y_test, y_pred_rf)
disp_rf = ConfusionMatrixDisplay(confusion_matrix=cm_rf, display_labels=["Legit", "Fraud"])
disp_rf.plot(cmap="Greens")
plt.title("Figure 9: Confusion Matrix - Random Forest")
plt.show()

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Assuming X_train and y_train are defined and available from previous code
# Define the XGBoost model and assign it to xgb_model
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
xgb_model.fit(X_train, y_train)  # Train the model

# Now you can use xgb_model in ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(xgb_model, X_test, y_test)
ConfusionMatrixDisplay.from_estimator(xgb_model, X_test, y_test)
plt.title("Figure 10: Confusion Matrix - XGBoost")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [07:45:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
y_scores = logistic_model.predict_proba(X_test)[:,1]
y_scores = logistic_model.predict_proba(X_test)[:,1]
precision, recall, _ = precision_recall_curve(y_test, y_scores)
plt.plot(recall, precision)
plt.title("Figure 11: Precision-Recall Curve - Logistic Regression")
plt.show()

# %%
y_scores = rf_model.predict_proba(X_test)[:,1]
y_scores = rf_model.predict_proba(X_test)[:,1]
precision, recall, _ = precision_recall_curve(y_test, y_scores)
plt.plot(recall, precision)
plt.title("Figure 12: Precision-Recall Curve - Random Forest")
plt.show()

# %%
y_scores = xgb_model.predict_proba(X_test)[:,1]
y_scores = xgb_model.predict_proba(X_test)[:,1]
precision, recall, _ = precision_recall_curve(y_test, y_scores)
plt.plot(recall, precision)
plt.title("Figure 13: Precision-Recall Curve - XGBoost")
plt.show()

# %%
scores = {'Logistic Regression': 0.88, 'Random Forest': 0.9978, 'XGBoost': 0.999}
plt.bar(scores.keys(), scores.values())
plt.ylabel("F1 Score")
plt.title("Figure 14: F1 Scores Across Models")
plt.show()

# %%
precisions = {'Logistic Regression': 0.96, 'Random Forest': 0.9990, 'XGBoost': 0.9982}
plt.bar(precisions.keys(), precisions.values())
plt.ylabel("Precision")
plt.title("Figure 15: Precision Across Models")
plt.show()

# %%
recalls = {'Logistic Regression': 0.88, 'Random Forest': 0.9966, 'XGBoost': 0.9998}
plt.bar(recalls.keys(), recalls.values())
plt.ylabel("Recall")
plt.title("Figure 16: Recall Across Models")
plt.show()

# %%
import pandas as pd
metrics = {'Model': ['Logistic Regression', 'Random Forest', 'XGBoost'],
           'F1 Score': [0.92, 0.9978, 0.999],
           'Precision': [0.96, 0.9990, 0.9982],
           'Recall': [0.88, 0.9966, 0.9998]}
pd.DataFrame(metrics)
# Out:
#                  Model  F1 Score  Precision  Recall
# 0  Logistic Regression    0.9200     0.9600  0.8800
# 1        Random Forest    0.9978     0.9990  0.9966
# 2              XGBoost    0.9990     0.9982  0.9998

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression  # Or any other model you want to use

# Assuming you have X_train, y_train from previous cells
model = LogisticRegression()

# Perform cross-validation and store the scores
cross_val_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy') # Example using accuracy
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression  # Or any other model you want to use

# Assuming you have X_train, y_train from previous cells
model = LogisticRegression()

# Perform cross-validation and store the scores
cross_val_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy') # Example using accuracy

# Now you can plot the scores
sns.histplot(cross_val_scores)
plt.show()
